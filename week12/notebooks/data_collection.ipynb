# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:/week12/data/raw/customer_churn.csv")

# %%
df
# Out:
#     Customer_ID  Tenure  MonthlyCharges  TotalCharges        Contract  \
# 0        C00001       6              64          1540        One year
# 1        C00002      21             113          1753  Month-to-month
# 2        C00003      27              31          1455        Two year
# 3        C00004      53              29          7150  Month-to-month
# 4        C00005      16             185          1023        One year
# ..          ...     ...             ...           ...             ...
# 495      C00496      50             128          6970  Month-to-month
# 496      C00497       2              49          5917        Two year
# 497      C00498      46             198          2158  Month-to-month
# 498      C00499       1             185          5755        Two year
# 499      C00500      27             181          4292  Month-to-month
#
#         PaymentMethod PaperlessBilling  SeniorCitizen  Churn
# 0         Credit Card               No              1      0
# ...

# %%
print(df.shape)       # Rows, columns
print(df.info())      # Data types, non-null counts
print(df.head())      # First few rows
# Out:
# (500, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       500 non-null    object
#  1   Tenure            500 non-null    int64
#  2   MonthlyCharges    500 non-null    int64
#  3   TotalCharges      500 non-null    int64
#  4   Contract          500 non-null    object
#  5   PaymentMethod     500 non-null    object
#  6   PaperlessBilling  500 non-null    object
#  7   SeniorCitizen     500 non-null    int64
#  8   Churn             500 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 35.3+ KB
# None
#   Customer_ID  Tenure  MonthlyCharges  TotalCharges        Contract  \
# 0      C00001       6              64          1540        One year
# 1      C00002      21             113          1753  Month-to-month
# 2      C00003      27              31          1455        Two year
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Customer_ID         0
# Tenure              0
# MonthlyCharges      0
# TotalCharges        0
# Contract            0
# PaymentMethod       0
# PaperlessBilling    0
# SeniorCitizen       0
# Churn               0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
# Check column data types
print(df.dtypes)

# Convert TotalCharges to numeric (handle errors)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Out:
# Customer_ID         object
# Tenure               int64
# MonthlyCharges       int64
# TotalCharges         int64
# Contract            object
# PaymentMethod       object
# PaperlessBilling    object
# SeniorCitizen        int64
# Churn                int64
# dtype: object

# %%
# Distribution of churn
churn_counts = df['Churn'].value_counts()
print(churn_counts)

# Visualize
sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.show()
# Out:
# Churn
# 0    447
# 1     53
# Name: count, dtype: int64

# %% [markdown]
# day2

# %% [markdown]
# ### Day 2 Findings: Data Collection
#
# - Dataset contains 500 rows and 9 columns.
# - No missing values detected.
# - Data types are consistent: categorical (Contract, PaymentMethod, PaperlessBilling), numeric (Tenure, MonthlyCharges, TotalCharges, SeniorCitizen).
# - Target variable `Churn` is numeric (0/1), will be converted to categorical for clarity.
# - Churn distribution is highly imbalanced (~11% churn vs ~89% non-churn).
