# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("D:\week 8\data\cleaned_data.csv")

# %%
import matplotlib.ticker as ticker

plt.figure(figsize=(14, 7))
sns.boxenplot(y="price", x="state", data=df, palette="deep")
plt.xticks(rotation=55)
plt.yscale('log')

# Format y-axis ticks to plain numbers
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter())
plt.gca().yaxis.set_minor_formatter(ticker.NullFormatter())  # Optional: hide minor ticks
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.show()
# Out:
# C:\Users\Kaif\AppData\Local\Temp\ipykernel_14636\1299005234.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(y="price", x="state", data=df, palette="deep")

# %%
df["state"].unique()
# Out:
# array(['Puerto Rico', 'Virgin Islands', 'Massachusetts', 'Connecticut',
#        'New Hampshire', 'Vermont', 'New Jersey', 'New York',
#        'South Carolina', 'Tennessee', 'Rhode Island', 'Virginia',
#        'Wyoming', 'Maine', 'Georgia', 'Pennsylvania', 'West Virginia',
#        'Delaware', 'Louisiana', 'Ohio', 'California', 'Colorado',
#        'Maryland', 'Missouri', 'District of Columbia', 'Wisconsin',
#        'North Carolina', 'Kentucky', 'Michigan', 'Mississippi', 'Florida',
#        'Alabama', 'New Brunswick', nan, 'Texas', 'Arkansas', 'Idaho',
#        'Indiana', 'Illinois', 'New Mexico', 'Iowa', 'Minnesota',
#        'South Dakota', 'Nebraska', 'North Dakota', 'Montana', 'Oklahoma',
#        'Kansas', 'Oregon', 'Utah', 'Nevada', 'Washington', 'Arizona',
#        'Hawaii', 'Guam', 'Alaska'], dtype=object)

# %% [markdown]
# THESE ARE ALL THE STATES FROM THE DATASET

# %% [markdown]
# INSTEAD OF TAKING ALL THE STATES WHICH WILL BE MESSY EDA
# LETS ONLY TAKE THE NYC DATA FROM NEWYORK STATE

# %%
new_york=df[df["state"]=="New York"]

# %%
bednewyor = new_york.copy()
bednewyor["bed"] = pd.to_numeric(bednewyor["bed"], errors="coerce")
bednewyor = bednewyor.sort_values(by="bed")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

plt.figure(figsize=(16, 8))  
sns.barplot(
    y="price", 
    x="bed", 
    data=bednewyor,  
)



plt.ylabel("Price")
plt.xlabel("Bedrooms")
plt.title("House Prices by Number of Bedrooms")
plt.show()

# %% [markdown]
# this barplot shows the price of the house with respect to bedsize,
# we can see that there is very least co-relation between price and bedsize

# %%
plt.figure(figsize=(10,10))
sns.heatmap(new_york.select_dtypes(include='number').corr(), annot=True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# from this cmap we know that there is a corelation between price,bed,bath and brokered_by

# %% [markdown]
# lets only find out the trends and business opportunity in newyork city

# %%
nyc=df[df["city"]=="New York City"]

# %%
nyc.describe()
# Out:
#          brokered_by         price           bed          bath      acre_lot  \
# count   12634.000000  1.263400e+04  12634.000000  12634.000000  12634.000000
# mean    36268.518366  2.266022e+06      2.454241      2.132986     12.466265
# std     24546.703302  4.176101e+06      2.094567      1.949035      7.976343
# min       402.000000  1.000000e+00      1.000000      1.000000      0.000000
# 25%     23592.000000  6.650000e+05      1.000000      1.000000     15.223027
# 50%     24196.000000  1.195000e+06      2.000000      2.000000     15.223027
# 75%     41924.000000  2.298497e+06      3.000000      3.000000     15.223027
# max    109331.000000  1.690000e+08    123.000000    123.000000    625.000000
#
#              street      zip_code    house_size
# count  1.263400e+04  12634.000000  12634.000000
# mean   8.854213e+05  10445.592845   1106.761991
# std    4.780587e+05    563.264535   1779.684850
# min    6.106000e+03  10001.000000      0.000000
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(nyc.select_dtypes(include='number').corr(), annot=True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# from this cmap we know that there is a corelation between price,bed,bath and brokered_by

# %%
sns.catplot(x="bed", y="price", kind='bar', data=nyc) 
plt.figure(figsize=(15,20))
sns.catplot(x="bath", y="price", kind='bar', data=nyc) 
plt.figure(figsize=(15,20))

# %%
sns.histplot(x="brokered_by", y="price", data=nyc) 
plt.figure(figsize=(100,20))

# %%
plt.figure(figsize=(100,20))
sns.barplot(x="house_size",y="price",data=nyc)
plt.show()

# %% [markdown]
# from the eda we have a data output saying that price,bed,bath and brokered_by can be used for further analysis for business opportunity and the predictions can be performed using these coloumns
